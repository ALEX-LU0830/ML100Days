# %%
import numpy as np
import pandas as pd

# %%
data = {
    'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
    'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
    'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']
}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(data, index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
#filter=(df["column name"]="name")
A=df[(df["animal"]=="cat")].age.mean()
B=df[(df["animal"]=="dog")].age.mean()
C=df[(df["animal"]=="snake")].age.mean()
print(A,B,C)
# Out:
# 2.5 5.0 2.5

# %%
df1=df.sort_values(by=['age'])
df1
# Out:
#   animal  age  visits priority
# c  snake  0.5       2       no
# f    cat  2.0       3       no
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# j    dog  3.0       1       no
# g  snake  4.5       1       no
# e    dog  5.0       2       no
# i    dog  7.0       2       no
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df2=df.sort_values(by='visits',ascending=False)
df2
# Out:
#   animal  age  visits priority
# b    cat  3.0       3      yes
# d    dog  NaN       3      yes
# f    cat  2.0       3       no
# c  snake  0.5       2       no
# e    dog  5.0       2       no
# i    dog  7.0       2       no
# a    cat  2.5       1      yes
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# j    dog  3.0       1       no

# %%
#df.replace({'column name':{'stuff':'replacing name'}})
df.replace({'priority': {'yes': True, 'no': False}})
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  2.0       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False
# j    dog  3.0       1     False

# %%
df1 = pd.DataFrame(np.random.random(size=(5, 3)))
df1
# Out:
#           0         1         2
# 0  0.075569  0.666228  0.428639
# 1  0.053156  0.875231  0.310501
# 2  0.162832  0.754554  0.001008
# 3  0.782460  0.982661  0.268678
# 4  0.602603  0.057310  0.535881

# %%
#df.sub(df.mean(axis=1), axis=0)
df1.mean(axis=0)
df1.sub(df1.mean(axis=0),axis=1)
# Out:
#           0         1         2
# 0 -0.259755 -0.000969  0.119698
# 1 -0.282168  0.208034  0.001559
# 2 -0.172492  0.087358 -0.307933
# 3  0.447136  0.315464 -0.040264
# 4  0.267279 -0.609887  0.226940

# %%
df1.mean(axis=1)
df1.sub(df1.mean(axis=1),axis=0)
# Out:
#           0         1         2
# 0 -0.314577  0.276083  0.038494
# 1 -0.359806  0.462268 -0.102462
# 2 -0.143300  0.448423 -0.305123
# 3  0.104527  0.304728 -0.409255
# 4  0.204005 -0.341288  0.137283

# %%
A= pd.Series(df1.sum(axis=1))
print(A.argmin())
# Out:
# 2

# %%
A= pd.Series(df1.sum(axis=0))
print(A.argmin())
# Out:
# 2
